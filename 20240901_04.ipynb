# %% [markdown]
# # SIGNATE Cup 2024
#
# ## 概要
#
# - 説明変数
#     - 元データの各カラムをデータクレンジングしたもの
#     - タイポフラグ
#     - 欠損フラグ
# - 説明変数の前処理
#     - `Age` `DurationOfPitch` `MonthlyIncome` を数値変数、それ以外をカテゴリー変数をみなした。
#     - 数値変数は正規化と欠損値補完 (`IterativeImputer`) を、カテゴリー変数はダミー変数化をそれぞれ施した。
#     - L1正則化で絞り込んだ後、CVを見ながら手作業で変数を選択した。
# - モデル
#     - ロジスティック回帰モデル
# - モデル選択
#     - `StratifiedShuffleSplit(n_splits=100, test_size=0.5)`
# - アンサンブル
#     - なし
# - スコア
#     - CV: 0.8472193
#     - Public LB: 0.8391560
#     - Private LB: 0.8388465

# %% [markdown]
# ## セットアップ

# %%
import numpy as np
import pandas as pd

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %%
train_raw = pd.read_csv('rawdata/train.csv')
test_raw = pd.read_csv('rawdata/test.csv')

# %% [markdown]
# ## 前処理

# %%
def cleanse(dirty):
    # データクレンジング

    clean = dirty.copy()

    clean['Age'] = (
        dirty['Age']
        .str.normalize('NFKC')
        .str.replace(r'[歳才際代]', '', regex=True)
        .replace({
            f'{c2}十{c1}'.replace('零十', '').replace('一十', '十').replace('零', ''): f'{n2 * 10 + n1}'
            for n2, c2 in enumerate('零一二三四五六七八九')
            for n1, c1 in enumerate('零一二三四五六七八九')
        })
        .astype(float)
    )
    clean['AgeTypo'] = dirty['Age'].str.extract(r'([歳才際代])')[0]
    clean['Age漢数字'] = dirty['Age'].str.contains(r'[一二三四五六七八九]', na=False)

    clean['DurationOfPitch'] = (
        dirty['DurationOfPitch']
        .str.extract(r'(\d+)([秒分])')
        .pipe(lambda df: df[0].astype(float) * np.where(df[1] == '分', 60, 1))
    )
    clean['DurationOfPitch分'] = dirty['DurationOfPitch'].str.contains('分', na=False)

    clean['Gender'] = (
        dirty['Gender']
        .str.normalize('NFKC')
        .str.lower()
        .str.replace(' ', '')
    )
    clean['Gender全角'] = dirty['Gender'].str.normalize('NFKC') != dirty['Gender']
    clean['GenderSpace'] = dirty['Gender'].str.contains('\s')

    clean['NumberOfFollowups'] = dirty['NumberOfFollowups'].mask(lambda s: s >= 100, lambda s: s / 100)
    clean['NumberOfFollowupsTypo'] = dirty['NumberOfFollowups'] >= 100

    clean['ProductPitched'] = dirty['ProductPitched'].apply(lambda x: len(x))
    clean['ProductPitchedTypo'] = (
        dirty['ProductPitched']
        .str.lower()
        .str.contains(r'[^a-z\s]')
    )

    clean['NumberOfTrips'] = (
        dirty['NumberOfTrips']
        .str.extract(r'([^\d]*)(\d)回?')
        .pipe(lambda df: np.select([df[0] == '年に', df[0] == '半年に', df[0] == '四半期に'], [1, 2, 4], 1) * df[1].astype(float))
    )
    clean['NumberOfTripsFreq'] = (
        dirty['NumberOfTrips']
        .str.extract(r'^([^\d]*)')[0]
        .mask(lambda s: s == '', np.nan)
    )

    clean['Designation'] = dirty['Designation'].apply(lambda x: len(x))
    clean['DesignationTypo'] = dirty['Designation'].str.lower().str.contains(r'[^a-z\s]')

    clean['MonthlyIncome'] = (
        dirty['MonthlyIncome']
        .str.extract(r'([\d\.]+)([^\d\.]*)')
        .pipe(lambda df: df[0].astype(float) * np.where(df[1] == '', 1, 10000))
    )
    clean['MonthlyIncome万円'] = dirty['MonthlyIncome'].str.contains(r'[^\d\.]', na=False)

    customer_info_split = (
        dirty['customer_info']
        .str.normalize('NFKC')
        .str.split(r'[、,/\s]', n=3)
    )
    clean['MaritalStatus'] = customer_info_split.apply(lambda x: x[0])
    clean['OwnCar'] = np.where(customer_info_split.apply(lambda x: x[1]).str.contains('なし|未'), 0, 1)
    clean['NumberOfChildrenVisiting'] = (
        customer_info_split
        .apply(lambda x: x[2])
        .mask(lambda s: s == '子供有り', '1.4')  # 人数がわからない場合、平均人数を格納する。
        .mask(lambda s: s.str.contains('ゼロ|なし|無|非'), '0')
        .str.extract('([\d\.]+)')[0]
        .astype(float)
    )

    return clean

# %%
def trim(traintest):
    # 似た傾向を持つ値をまとめる。

    traintest = traintest.copy()

    traintest['Age'] = traintest['Age'].mask(traintest['Age'] >= 40, 40)
    traintest['MonthlyIncome'] = traintest['MonthlyIncome'].mask(traintest['MonthlyIncome'] >= 350000, 350000)

    return traintest

# %%
def get_dummies(traintest):
    # カテゴリー変数をダミー変数化する。

    traintest = pd.get_dummies(
        traintest,
        dummy_na=True,
        columns = [
            'AgeTypo',
            'TypeofContact',
            'CityTier',
            'Occupation',
            'Gender',
            'NumberOfPersonVisiting',
            'NumberOfFollowups',
            'ProductPitched',
            'PreferredPropertyStar',
            'NumberOfTrips',
            'NumberOfTripsFreq',
            'PitchSatisfactionScore',
            'Designation',
            'MaritalStatus',
            'NumberOfChildrenVisiting'
        ]
    )
    traintest = traintest.rename(columns = lambda column: column.replace('.0', ''))

    return traintest

# %%
def standardize(traintest):
    # 数値変数を正規化する。

    traintest = traintest.copy()

    scale = lambda s: (s - s.mean()) / s.std()
    traintest['Age'] = (traintest['Age'] - 30) / 20
    traintest['DurationOfPitch'] = scale(traintest['DurationOfPitch'])
    traintest['MonthlyIncome'] = (traintest['MonthlyIncome'] - 300000) / 100000

    return traintest

# %%
def dummyna_fillna(traintest):
    # 欠損フラグを立てたうえで、欠損値を補完する。

    traintest = traintest.copy()

    for column in traintest.columns.drop(['ProdTaken']):
        if traintest[column].isna().any():
            traintest[f'{column}_nan'] = traintest[column].isna()

    columns = traintest.columns.drop(['id', 'customer_info', 'ProdTaken', 'task'])
    imputer = IterativeImputer(max_iter=10, random_state=0)
    traintest[columns] = imputer.fit_transform(traintest[columns])

    return traintest

# %%
traintest = pd.concat([
    train_raw.assign(task='train'),
    test_raw.assign(task='test')
], ignore_index=True)

traintest = cleanse(traintest)
traintest = trim(traintest)
traintest = get_dummies(traintest)
traintest = standardize(traintest)
traintest = dummyna_fillna(traintest)

train = traintest.loc[lambda df: df['task'] == 'train', :].drop(columns = ['task'])
test = traintest.loc[lambda df: df['task'] == 'test', :].drop(columns = ['task'])

# %% [markdown]
# ## 学習

# %% [markdown]
# ### 変数選択

# %%
# 説明変数
feature_columns = [
    'Age',
    'AgeTypo_際',
    'AgeTypo_代',
    'TypeofContact_Company Invited',
    'CityTier_1',
    'Occupation_Large Business',
    'Gender_male',
    'NumberOfPersonVisiting_4',
    'NumberOfFollowups_1',
    'NumberOfFollowups_6',
    'NumberOfFollowupsTypo',
    'ProductPitched_6',
    'PreferredPropertyStar_4',
    'NumberOfTrips_2',
    'NumberOfTrips_5',
    'NumberOfTrips_7',
    'NumberOfTrips_nan',
    'Passport',
    'PitchSatisfactionScore_1',
    'Designation_9',
    'MonthlyIncome',
    'MaritalStatus_独身',
    'OwnCar',
    'NumberOfChildrenVisiting_2',
    'NumberOfChildrenVisiting_3',
    'NumberOfChildrenVisiting_nan'
]

# 目的変数
target_column = 'ProdTaken'

# %% [markdown]
# ### クロスバリデーション

# %%
folds = StratifiedShuffleSplit(n_splits=100, test_size=0.5, random_state=0)
cv_models = []
cv_scores = []
cv_trains = []
cv_tests = []
for i, (cv_train_index, cv_test_index) in enumerate(folds.split(train[feature_columns], train[target_column])):
    cv_train = train.iloc[cv_train_index, :].copy()
    cv_test = train.iloc[cv_test_index, :].copy()

    cv_model = LogisticRegression(solver='liblinear', penalty='l2', C=1.0, random_state=0)
    cv_model = cv_model.fit(cv_train[feature_columns], cv_train[target_column])
    cv_models.append(cv_model)

    cv_test[f'{target_column}_pred'] = cv_model.predict_proba(cv_test[feature_columns])[:, 1]
    cv_score = roc_auc_score(cv_test[target_column], cv_test[f'{target_column}_pred'])
    cv_scores.append(cv_score)

    cv_trains.append(cv_train)
    cv_tests.append(cv_test)

print(f'{np.mean(cv_scores)} ± {np.std(cv_scores)}')
# Out:
# 0.8472193184502718 ± 0.008458509561811087

# %%
# アンサンブルした場合のスコア
cv_tests_all = pd.concat([cv_test.assign(k = k) for k, cv_test in enumerate(cv_tests)])
cv_tests_all['ProdTaken_pred_rank'] = cv_tests_all.groupby('k')['ProdTaken_pred'].rank()
roc_auc_score(
    cv_tests_all.groupby('id')['ProdTaken'].mean(),
    cv_tests_all.groupby('id')['ProdTaken_pred_rank'].mean()
)
# Out:
# 0.8524458919291147

# %%
# 回帰係数
(
    pd.concat([
        pd.DataFrame({
            'feature': cv_model.feature_names_in_,
            'coef': cv_model.coef_[0]
        })
        for cv_model in cv_models
    ])
    .groupby('feature', as_index=False)['coef'].agg(['mean', 'std'])
    .sort_values('feature', ignore_index=True)
    .style.bar(vmin=-1.0, vmax=1.0)
)
# Out:
# <style type="text/css">
# #T_966f8_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.2%, #d65f5f 2.2%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 59.2%, transparent 59.2%);
# }
# #T_966f8_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.2%, #d65f5f 18.2%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row1_col2, #T_966f8_row16_col2, #T_966f8_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 60.2%, transparent 60.2%);
# }
# #T_966f8_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.9%, #d65f5f 28.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 63.9%, transparent 63.9%);
# }
# #T_966f8_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 8.4%, #d65f5f 8.4%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 56.1%, transparent 56.1%);
# }
# #T_966f8_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 91.6%, transparent 91.6%);
# }
# #T_966f8_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 58.0%, transparent 58.0%);
# }
# #T_966f8_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 85.4%, transparent 85.4%);
# }
# #T_966f8_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 56.2%, transparent 56.2%);
# }
# #T_966f8_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 90.1%, transparent 90.1%);
# }
# #T_966f8_row6_col2, #T_966f8_row23_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 56.3%, transparent 56.3%);
# }
# #T_966f8_row7_col1, #T_966f8_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 60.4%, transparent 60.4%);
# }
# #T_966f8_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.0%, #d65f5f 33.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 57.1%, transparent 57.1%);
# }
# #T_966f8_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 31.3%, #d65f5f 31.3%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 65.9%, transparent 65.9%);
# }
# #T_966f8_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.0%, #d65f5f 18.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row10_col2, #T_966f8_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 57.4%, transparent 57.4%);
# }
# #T_966f8_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.0%, #d65f5f 26.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 64.6%, transparent 64.6%);
# }
# #T_966f8_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.0%, #d65f5f 22.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 65.6%, transparent 65.6%);
# }
# #T_966f8_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 94.2%, transparent 94.2%);
# }
# #T_966f8_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 65.4%, transparent 65.4%);
# }
# #T_966f8_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.6%, #d65f5f 29.6%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 63.3%, transparent 63.3%);
# }
# #T_966f8_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.1%, #d65f5f 27.1%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 58.1%, transparent 58.1%);
# }
# #T_966f8_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.7%, #d65f5f 32.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 79.4%, transparent 79.4%);
# }
# #T_966f8_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 79.8%, transparent 79.8%);
# }
# #T_966f8_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 69.9%, transparent 69.9%);
# }
# #T_966f8_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 67.0%, transparent 67.0%);
# }
# #T_966f8_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.1%, #d65f5f 36.1%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row20_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 55.2%, transparent 55.2%);
# }
# #T_966f8_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_966f8_row21_col2, #T_966f8_row22_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 57.7%, transparent 57.7%);
# }
# #T_966f8_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.1%, #d65f5f 25.1%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_966f8_row23_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 66.0%, transparent 66.0%);
# }
# #T_966f8_row24_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 58.7%, transparent 58.7%);
# }
# #T_966f8_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 70.0%, transparent 70.0%);
# }
# #T_966f8_row25_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 55.3%, transparent 55.3%);
# }
# </style>
# <table id="T_966f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_966f8_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_966f8_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_966f8_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_966f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_966f8_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_966f8_row0_col1" class="data row0 col1" >-0.956760</td>
#       <td id="T_966f8_row0_col2" class="data row0 col2" >0.184319</td>
#     </tr>
#     <tr>
#       <th id="T_966f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_966f8_row1_col0" class="data row1 col0" >AgeTypo_代</td>
#       <td id="T_966f8_row1_col1" class="data row1 col1" >-0.635645</td>
#       <td id="T_966f8_row1_col2" class="data row1 col2" >0.203097</td>
#     </tr>
#     <tr>
#       <th id="T_966f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_966f8_row2_col0" class="data row2 col0" >AgeTypo_際</td>
#       <td id="T_966f8_row2_col1" class="data row2 col1" >-0.422092</td>
#       <td id="T_966f8_row2_col2" cla

# %% [markdown]
# ### 予測用モデルの学習

# %%
model = LogisticRegression(solver='liblinear', penalty='l2', C=1.0, random_state=0)
model = model.fit(train[feature_columns], train[target_column])

# %%
# 回帰係数
(
    pd.DataFrame({
        'feature': model.feature_names_in_,
        'coef': model.coef_[0]
    })
    .sort_values('feature', ignore_index=True)
    .style.bar(vmin=-1.0, vmax=1.0)
)
# Out:
# <style type="text/css">
# #T_77615_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 2.5%, #d65f5f 2.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 17.0%, #d65f5f 17.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.2%, #d65f5f 29.2%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 9.1%, #d65f5f 9.1%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 92.6%, transparent 92.6%);
# }
# #T_77615_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 85.2%, transparent 85.2%);
# }
# #T_77615_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 90.5%, transparent 90.5%);
# }
# #T_77615_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.1%, #d65f5f 0.1%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.0%, #d65f5f 33.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.8%, #d65f5f 25.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.9%, #d65f5f 0.9%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.1%, #d65f5f 21.1%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 21.5%, #d65f5f 21.5%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row13_col1, #T_77615_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_77615_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.7%, #d65f5f 32.7%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.3%, #d65f5f 27.3%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.2%, #d65f5f 34.2%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 81.8%, transparent 81.8%);
# }
# #T_77615_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 89.7%, transparent 89.7%);
# }
# #T_77615_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 66.7%, transparent 66.7%);
# }
# #T_77615_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.3%, #d65f5f 36.3%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.8%, #d65f5f 26.8%, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row23_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 65.8%, transparent 65.8%);
# }
# #T_77615_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 50.0%, transparent 50.0%);
# }
# #T_77615_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #d65f5f 50.0%, #d65f5f 70.4%, transparent 70.4%);
# }
# </style>
# <table id="T_77615">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77615_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_77615_level0_col1" class="col_heading level0 col1" >coef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77615_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77615_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_77615_row0_col1" class="data row0 col1" >-0.950265</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77615_row1_col0" class="data row1 col0" >AgeTypo_代</td>
#       <td id="T_77615_row1_col1" class="data row1 col1" >-0.659465</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77615_row2_col0" class="data row2 col0" >AgeTypo_際</td>
#       <td id="T_77615_row2_col1" class="data row2 col1" >-0.415532</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77615_row3_col0" class="data row3 col0" >CityTier_1</td>
#       <td id="T_77615_row3_col1" class="data row3 col1" >-0.818671</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77615_row4_col0" class="data row4 col0" >Designation_9</td>
#       <td id="T_77615_row4_col1" class="data row4 col1" >0.852965</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_77615_row5_col0" class="data row5 col0" >Gender_male</td>
#       <td id="T_77615_row5_col1" class="data row5 col1" >0.703024</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_77615_row6_col0" class="data row6 col0" >MaritalStatus_独身</td>
#       <td id="T_77615_row6_col1" class="data row6 col1" >0.809665</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_77615_row7_col0" class="data row7 col0" >MonthlyIncome</td>
#       <td id="T_77615_row7_col1" class="data row7 col1" >-0.997521</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_77615_row8_col0" class="data row8 col0" >NumberOfChildrenVisiting_2</td>
#       <td id="T_77615_row8_col1" class="data row8 col1" >-0.340442</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_77615_row9_col0" class="data row9 col0" >NumberOfChildrenVisiting_3</td>
#       <td id="T_77615_row9_col1" class="data row9 col1" >-0.484049</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_77615_row10_col0" class="data row10 col0" >NumberOfChildrenVisiting_nan</td>
#       <td id="T_77615_row10_col1" class="data row10 col1" >-0.982266</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_77615_row11_col0" class="data row11 col0" >NumberOfFollowupsTypo</td>
#       <td id="T_77615_row11_col1" class="data row11 col1" >-0.577339</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_77615_row12_col0" class="data row12 col0" >NumberOfFollowups_1</td>
#       <td id="T_77615_row12_col1" class="data row12 col1" >-0.569252</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_77615_row13_col0" class="data row13 col0" >NumberOfFollowups_6</td>
#       <td id="T_77615_row13_col1" class="data row13 col1" >1.031606</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_77615_row14_col0" class="data row14 col0" >NumberOfPersonVisiting_4</td>
#       <td id="T_77615_row14_col1" class="data row14 col1" >-0.346168</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_77615_row15_col0" class="data row15 col0" >NumberOfTrips_2</td>
#       <td id="T_77615_row15_col1" class="data row15 col1" >-0.454556</td>
#     </tr>
#     <tr>
#       <th id="T_77615_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_77615_row16_col0" class="data

# %% [markdown]
# ## 予測

# %%
test[target_column] = model.predict_proba(test[feature_columns])[:, 1]

# %% [markdown]
# ## 提出

# %%
# submit = test[['id', target_column]].copy()
# submit.to_csv('submit/submit_20240901_04.csv', index=False, header=False)
